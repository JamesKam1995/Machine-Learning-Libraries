# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as T
import torch.optim as optim
from torch.utils.data import sampler
from torchvision.models import vgg19

import SRGAN_pytorch
print(dir(SRGAN_pytorch))
# Out:
# ['Discriminator', 'Generator', 'ResnetBlock', 'T', 'VGG_loss', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'nn', 'np', 'optim', 'sampler', 'test', 'torch', 'torchvision', 'upsampling_block', 'vgg19']

# %%
import tensorflow_datasets as tfds
import tensorflow as tf

# Choose one of the bicubic configurations, e.g., 4× super-resolution
div2k_train = tfds.load(
    'div2k/bicubic_x4', 
    split='train', 
    as_supervised=True  # returns (lr, hr) image pairs
)

div2k_valid = tfds.load(
    'div2k/bicubic_x4',
    split='validation',
    as_supervised=True
)

# Example usage
for lr, hr in div2k_train.take(1):
    print("Low-resolution:", lr.shape)
    print("High-resolution:", hr.shape)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import tensorflow_datasets as tfds
#       2 import tensorflow as tf
#       4 # Choose one of the bicubic configurations, e.g., 4× super-resolution
#
# ModuleNotFoundError: No module named 'tensorflow_datasets'

# %%
pip install tensorflow
# Out:
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# ...
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/375.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/375.9 MB 812.7 kB/s eta 0:07:43
#    ---------------------------------------- 0.1/375.9 MB 435.7 kB/s eta 0:14:23
#    ---------------------------------------- 0.1/375.9 MB 435.7 kB/s eta 0:14:23
#    ---------------------------------------- 0.1/375.9 MB 403.5 kB/s eta 0:15:32
#    ---------------------------------------- 0.1/375.9 MB 368.6 kB/s eta 0:17:00
#    ---------------------------------------- 0.1/375.9 MB 359.9 kB/s eta 0:17:25
# ...
